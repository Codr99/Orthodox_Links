# %% [markdown]
# # Textos Litúrgicos Ortodoxos en Español
#
# Colección de enlaces HTML a textos litúrgicos de la Iglesia Ortodoxa disponibles en español,
# con recursos de las principales jurisdicciones que sirven a comunidades hispanohablantes:
# la Diócesis de México (OCA), la Arquidiócesis Antioquena de México, el Patriarcado Ecuménico
# (Arquidiócesis Ortodoxa de México), el Patriarcado de Serbia (España) y la Iglesia Ortodoxa
# de Rusia (textos del Obispo Alejandro).
#
# Campos de metadatos:
# - **source** — sitio o editorial
# - **jurisdiction** — OCA · Antiochian · EP · Serbian · ROC · General
# - **type** — Portal · Online · PDF · Print · Archive

# %% [markdown]
# ## 1. Portales Centrales / Central Digital Hubs
#
# | Fuente | Descripción | URL |
# |---|---|---|
# | Liturgia Digital | Portal completo de la Arquidiócesis Ortodoxa de México (EP) — español, griego, inglés | https://liturgia.mx/ |
# | Saint Jonah | Índice de recursos litúrgicos ortodoxos en español (múltiples fuentes) | https://saintjonah.org/online-orthodox-liturgical-texts-in-spanish/ |
# | Holy Annunciation | Directorio de recursos ortodoxos en español | https://holyannunciation.net/spanish |

# %% [markdown]
# ## 2. Diócesis de México — Iglesia Ortodoxa en América (OCA)
#
# La Diócesis de México de la OCA publica textos litúrgicos completos en español en ocamexico.org.
#
# | Texto | URL |
# |---|---|
# | Hub litúrgico | https://ocamexico.org/liturgicos.html |
# | Servicio Litúrgico | https://ocamexico.org/serviciolitrgicoocamexico.html |
# | Vísperas Mayores | https://ocamexico.org/visperas_mayores.html |
# | Mineo Festivo | https://ocamexico.org/mineofestivo.html |
# | Triodio Cuaresmal | https://www.ocamexico.org/triodiocuaresmal.html |
# | Sábado Santo | https://ocamexico.org/sabadosanto.html |

# %% [markdown]
# ## 3. Arquidiócesis Ortodoxa Antioquena de México (iglesiaortodoxa.org.mx)
#
# La Arquidiócesis Antioquena de México ofrece los principales oficios como PDFs descargables.
#
# | Texto | URL |
# |---|---|
# | El Keron — Revestirse y Proposición | http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/01-Keron_Revesirse_Propocision.pdf |
# | Divina Liturgia de San Juan Crisóstomo | http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/02-Liturgia_de_San_Juan_Crisostomo.pdf |
# | Divina Liturgia de San Basilio Magno | http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/04-Liturgia_de_San_Basilio_magno.pdf |
# | Liturgia de los Dones Presantificados | http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/05-Liturgia_de_los_Dones_Presantificados.pdf |
# | Vísperas | https://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/03-visperas.pdf |
# | Salmos de Maitines | http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/02-salmos_de_matines.pdf |
# | Pequeñas Completas | https://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/04-pequenias_completas.pdf |
# | Paráclesis — Canon de Súplicas | http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/08-Paraclesis.pdf |

# %% [markdown]
# ## 4. Iglesia Ortodoxa Española — Patriarcado de Serbia (iglesiaortodoxa.es)
#
# La parroquia española del Patriarcado de Serbia mantiene una biblioteca de PDFs litúrgicos
# en español (y también en catalán — no incluido aquí). Los PDFs se acceden desde la página
# de biblioteca o directamente con las URLs URL-codificadas.
#
# | Texto | URL |
# |---|---|
# | Biblioteca (hub) | https://www.iglesiaortodoxa.es/index.php?lan=es&area=biblioteca&pagina=biblioteca |
# | Divina Liturgia de San Juan Crisóstomo | https://www.iglesiaortodoxa.es/biblioteca/Divina%20Liturgia%20de%20San%20Juan%20Crisostomo.pdf |
# | Divina Liturgia — Eslavón-Castellano (bilingüe) | https://www.iglesiaortodoxa.es/biblioteca/liturgia%20eslavon_castellano.pdf |
# | Acatisto a la Santísima Madre de Dios | https://www.iglesiaortodoxa.es/biblioteca/Akatisto%20a%20la%20Santisima%20Madre%20de%20Dios.pdf |
# | Navidad — Texto Festivo | https://www.iglesiaortodoxa.es/biblioteca/NAVIDAD%20texto%20de%20la%20fiesta%20combinado%20con%20fijo%20de%20les%20Hores.pdf |
# | Sábado de Lázaro | https://www.iglesiaortodoxa.es/biblioteca/Sabado%20de%20Lazaro%20-%20Visperas%2C%20Maitines%20y%20Liturgia.pdf |
# | Gran Canon de San Andrés de Creta | https://www.iglesiaortodoxa.es/biblioteca/Gran%20Canon%20de%20San%20Andres%20de%20Creta.pdf |
# | Semana Santa Tomo I — Domingo de Ramos a Jueves Santo | https://www.iglesiaortodoxa.es/biblioteca/Triodion_Semana%20Santa_Tomo%20I_D%20Ramos%20a%20J%20Santo-P_Esteban_Diaz.pdf |
# | Semana Santa Tomo II — Viernes Santo a Domingo de Pascua | https://www.iglesiaortodoxa.es/biblioteca/Triodion_Semana%20Santa_Tomo%20II_Visperas%20Viernes%20Santo%20a%20D%20Pascua_P_Esteban_Diaz.pdf |

# %% [markdown]
# ## 5. Iglesia Ortodoxa Santísima Virgen María — Chile (iglesiaortodoxa.cl)
#
# La iglesia ortodoxa chilena publica tres textos de oficio en PDF.
#
# | Texto | URL |
# |---|---|
# | Hub litúrgico | https://www.iglesiaortodoxa.cl/liturgicos |
# | Divina Liturgia (texto online) | https://www.iglesiaortodoxa.cl/divina-liturgia |
# | Divina Liturgia (PDF) | https://www.iglesiaortodoxa.cl/_files/ugd/aa7bfd_b7e96c7938cf4f87aa88bf61b829414f.pdf |
# | Vísperas y Maitutinos (PDF) | https://www.iglesiaortodoxa.cl/_files/ugd/1ea6a5_ef7ec48d556048d3b218e45d96b77664.pdf |
# | Funeral (PDF) | https://www.iglesiaortodoxa.cl/_files/ugd/aa7bfd_70e0f2ccf9594257aebbc5a4e2f97de3.pdf |

# %% [markdown]
# ## 6. Obispo Alejandro (Bishop Alexander Mileant) — Iglesia Ortodoxa Rusa
#
# El Obispo Alejandro (ROCOR/ROC, Los Ángeles) editó una amplia colección de materiales
# ortodoxos en español disponibles en fatheralexander.org.
#
# | Recurso | URL |
# |---|---|
# | Textos Litúrgicos en Español — hub | http://www.fatheralexander.org/page30.htm |
# | Divina Liturgia — inglés/español bilingüe | https://www.fatheralexander.org/booklets/spanish/liturgy_s_e.htm |

# %% [markdown]
# ## 7. Textos Litúrgicos Ortodoxos — Parroquia San Marcos, Irún (España)
#
# Sitio Google Sites mantenido por la parroquia ortodoxa de San Marcos (Irún, España),
# del Patriarcado de Serbia. Puede requerir inicio de sesión en Google para el índice principal.
#
# | Recurso | URL |
# |---|---|
# | Sitio principal | https://sites.google.com/site/textosliturgicosortodoxos/ |
# | Esquemas de los Oficios (Typikon) | https://sites.google.com/site/textosliturgicosortodoxos/typikon/esquemas |
# | Pentecostés — Pentecostarion | https://sites.google.com/site/textosliturgicosortodoxos/pentecostario/pascha11 |

# %% [markdown]
# ## 8. Ediciones Barek — Libros Litúrgicos Impresos (Arquidiócesis Antioquena, México)
#
# Ediciones Barek es la editorial litúrgica de la Arquidiócesis Antioquena de México.
# Sus libros se venden en MercadoLibre (México). Los enlaces apuntan a las fichas de producto.
#
# | Libro | URL |
# |---|---|
# | La Divina Liturgia de San Juan Crisóstomo | https://edicionesbarekac.mercadoshops.com.mx/MLM-778658033-la-divina-liturgia-de-san-juan-crisostomo-libro-ortodoxo-_JM |
# | Evangelio Litúrgico | https://edicionesbarekac.mercadoshops.com.mx/MLM-872645231-evangelio-liturgico-pasta-dura-_JM |
# | Colección de 8 Libros Litúrgicos | https://edicionesbarekac.mercadoshops.com.mx/MLM-1588866552-coleccion-de-libros-liturgicos-ortodoxos-8-libros-_JM |
# | Oficios de Semana Santa | https://edicionesbarekac.mercadoshops.com.mx/MLM-779506656-servicios-de-semana-santa-_JM |
# | Servicios de Cuaresma | https://articulo.mercadolibre.com.mx/MLM-875482485-servicios-de-cuaresma-_JM |

# %% [markdown]
# ## 9. Internet Archive, Typicon PDF y Portales de Referencia
#
# | Fuente | Recurso | URL |
# |---|---|---|
# | Internet Archive | Divina Liturgia de San Juan Crisóstomo (dominio público, 30 pp.) | https://archive.org/details/LaDivinaLiturgiaDeSanJuanCrisstomo |
# | Quotidian Typicon (EP) | Divinas Liturgias de San Juan Crisóstomo y San Basilio (PDF genérico) | https://quotidiantypicon.files.wordpress.com/2020/05/dl-jc-and-basil-generic-final.pdf |
# | OCA | Buenas Noticias en Español | https://www.oca.org/goodnews/espanol |
# | GOARCH | Recursos en Español | https://www.goarch.org/-/spanish-language-resources |
# | Logos Ortodoxo | La Divina Liturgia (artículo, Barcelona) | https://www.logosortodoxo.com/la-divina-liturgia/ |
# | Misión Ortodoxa CL | Textos Litúrgicos (Chile) | http://www.misionortodoxa.cl/index.php/publicaciones/textos-liturgicos |

# %% [markdown]
# ---
#
# ## Resumen — Recuento por Jurisdicción
#
# | Jurisdicción | Enlace(s) destacado(s) |
# |---|---|
# | OCA (México) | ocamexico.org — Litúrgicos, Vísperas, Triodio, etc. |
# | Antiochian (México) | iglesiaortodoxa.org.mx — 8 PDFs + Ediciones Barek |
# | EP (México) | liturgia.mx — portal completo español/griego/inglés |
# | Serbian (España) | iglesiaortodoxa.es — 9 PDFs; textosliturgicosortodoxos |
# | ROC | fatheralexander.org — hub + Divina Liturgia bilingüe |
# | General / Chile | iglesiaortodoxa.cl — 3 PDFs; archivo.org; referencias |

# %%
links = [
    {"source": 'Liturgia Digital', "jurisdiction": 'EP', "type": 'Portal',
     "title": 'Liturgia Digital — portal central (Arquidiócesis Ortodoxa de México, EP)',
     "url": 'https://liturgia.mx/'},
    {"source": 'Liturgia Digital', "jurisdiction": 'EP', "type": 'Online',
     "title": 'Servicios Litúrgicos — lista por fecha',
     "url": 'https://liturgia.mx/servicesindex'},
    {"source": 'Liturgia Digital', "jurisdiction": 'EP', "type": 'Online',
     "title": 'Libros Litúrgicos (sacramentos y oficios fijos)',
     "url": 'https://liturgia.mx/booksindex'},
    {"source": 'Saint Jonah', "jurisdiction": 'General', "type": 'Portal',
     "title": 'Saint Jonah — Índice de textos litúrgicos ortodoxos en español',
     "url": 'https://saintjonah.org/online-orthodox-liturgical-texts-in-spanish/'},
    {"source": 'Holy Annunciation', "jurisdiction": 'General', "type": 'Portal',
     "title": 'Holy Annunciation — Recursos sobre el cristianismo ortodoxo en español',
     "url": 'https://holyannunciation.net/spanish'},
    {"source": 'OCA Mexico', "jurisdiction": 'OCA', "type": 'Portal',
     "title": 'Litúrgicos — hub principal (Diócesis de México, OCA)',
     "url": 'https://ocamexico.org/liturgicos.html'},
    {"source": 'OCA Mexico', "jurisdiction": 'OCA', "type": 'Online',
     "title": 'Servicio Litúrgico',
     "url": 'https://ocamexico.org/serviciolitrgicoocamexico.html'},
    {"source": 'OCA Mexico', "jurisdiction": 'OCA', "type": 'Online',
     "title": 'Vísperas Mayores',
     "url": 'https://ocamexico.org/visperas_mayores.html'},
    {"source": 'OCA Mexico', "jurisdiction": 'OCA', "type": 'Online',
     "title": 'Mineo Festivo',
     "url": 'https://ocamexico.org/mineofestivo.html'},
    {"source": 'OCA Mexico', "jurisdiction": 'OCA', "type": 'Online',
     "title": 'Triodio Cuaresmal',
     "url": 'https://www.ocamexico.org/triodiocuaresmal.html'},
    {"source": 'OCA Mexico', "jurisdiction": 'OCA', "type": 'Online',
     "title": 'Sábado Santo',
     "url": 'https://ocamexico.org/sabadosanto.html'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'Portal',
     "title": 'Iglesia Ortodoxa Antioquena — sitio principal (México)',
     "url": 'https://www.iglesiaortodoxa.org.mx/'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'Online',
     "title": 'Evangelio Litúrgico (lecturas por fecha)',
     "url": 'https://iglesiaortodoxa.org.mx/informacion/class/evangelio-liturgico/'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'El Keron — Revestirse y Proposición',
     "url": 'http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/01-Keron_Revesirse_Propocision.pdf'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'Divina Liturgia de San Juan Crisóstomo',
     "url": 'http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/02-Liturgia_de_San_Juan_Crisostomo.pdf'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'Divina Liturgia de San Basilio Magno',
     "url": 'http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/04-Liturgia_de_San_Basilio_magno.pdf'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'Liturgia de los Dones Presantificados',
     "url": 'http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/liturgia/05-Liturgia_de_los_Dones_Presantificados.pdf'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'Vísperas',
     "url": 'https://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/03-visperas.pdf'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'Salmos de Maitines',
     "url": 'http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/02-salmos_de_matines.pdf'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'Pequeñas Completas',
     "url": 'https://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/04-pequenias_completas.pdf'},
    {"source": 'Antioquena MX', "jurisdiction": 'Antiochian', "type": 'PDF',
     "title": 'Paráclesis — Canon de Súplicas a la Virgen',
     "url": 'http://www.iglesiaortodoxa.org.mx/informacion/001-pdf/04-servicios_liturgicos/08-Paraclesis.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'Portal',
     "title": 'Iglesia Ortodoxa Española — Biblioteca (Patriarcado de Serbia)',
     "url": 'https://www.iglesiaortodoxa.es/index.php?lan=es&area=biblioteca&pagina=biblioteca'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Divina Liturgia de San Juan Crisóstomo (español)',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/Divina%20Liturgia%20de%20San%20Juan%20Crisostomo.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Divina Liturgia — Eslavón-Castellano (bilingüe)',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/liturgia%20eslavon_castellano.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Acatisto a la Santísima Madre de Dios',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/Akatisto%20a%20la%20Santisima%20Madre%20de%20Dios.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Navidad — Texto Festivo',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/NAVIDAD%20texto%20de%20la%20fiesta%20combinado%20con%20fijo%20de%20les%20Hores.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Sábado de Lázaro — Vísperas, Maitines y Liturgia',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/Sabado%20de%20Lazaro%20-%20Visperas%2C%20Maitines%20y%20Liturgia.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Domingo de Ramos — Pequeñas Vísperas, Vísperas, Maitines y Liturgia',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/Domingo%20de%20Ramos_Peque%C3%B1as%20V%C3%ADsperas%2C%20V%C3%ADsperas%2C%20Maitines%20y%20Liturgia.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Gran Canon de San Andrés de Creta',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/Gran%20Canon%20de%20San%20Andres%20de%20Creta.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Semana Santa Tomo I — Domingo de Ramos a Jueves Santo',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/Triodion_Semana%20Santa_Tomo%20I_D%20Ramos%20a%20J%20Santo-P_Esteban_Diaz.pdf'},
    {"source": 'iglesia.es', "jurisdiction": 'Serbian', "type": 'PDF',
     "title": 'Semana Santa Tomo II — Viernes Santo a Domingo de Pascua',
     "url": 'https://www.iglesiaortodoxa.es/biblioteca/Triodion_Semana%20Santa_Tomo%20II_Visperas%20Viernes%20Santo%20a%20D%20Pascua_P_Esteban_Diaz.pdf'},
    {"source": 'iglesia.cl', "jurisdiction": 'General', "type": 'Portal',
     "title": 'Iglesia Ortodoxa Chile — Textos Litúrgicos (hub)',
     "url": 'https://www.iglesiaortodoxa.cl/liturgicos'},
    {"source": 'iglesia.cl', "jurisdiction": 'General', "type": 'Online',
     "title": 'Divina Liturgia — texto y explicación',
     "url": 'https://www.iglesiaortodoxa.cl/divina-liturgia'},
    {"source": 'iglesia.cl', "jurisdiction": 'General', "type": 'PDF',
     "title": 'Divina Liturgia',
     "url": 'https://www.iglesiaortodoxa.cl/_files/ugd/aa7bfd_b7e96c7938cf4f87aa88bf61b829414f.pdf'},
    {"source": 'iglesia.cl', "jurisdiction": 'General', "type": 'PDF',
     "title": 'Vísperas y Maitutinos',
     "url": 'https://www.iglesiaortodoxa.cl/_files/ugd/1ea6a5_ef7ec48d556048d3b218e45d96b77664.pdf'},
    {"source": 'iglesia.cl', "jurisdiction": 'General', "type": 'PDF',
     "title": 'Funeral',
     "url": 'https://www.iglesiaortodoxa.cl/_files/ugd/aa7bfd_70e0f2ccf9594257aebbc5a4e2f97de3.pdf'},
    {"source": 'fatheralexander', "jurisdiction": 'ROC', "type": 'Portal',
     "title": 'Bishop Alexander — Textos Litúrgicos en Español (hub)',
     "url": 'http://www.fatheralexander.org/page30.htm'},
    {"source": 'fatheralexander', "jurisdiction": 'ROC', "type": 'Online',
     "title": 'Divina Liturgia de San Juan Crisóstomo — inglés/español (bilingüe)',
     "url": 'https://www.fatheralexander.org/booklets/spanish/liturgy_s_e.htm'},
    {"source": 'textosliturgicos.gs', "jurisdiction": 'Serbian', "type": 'Portal',
     "title": 'Textos Litúrgicos Ortodoxos — Parroquia San Marcos, Irún (España, Patr. Serbia)',
     "url": 'https://sites.google.com/site/textosliturgicosortodoxos/'},
    {"source": 'textosliturgicos.gs', "jurisdiction": 'Serbian', "type": 'Online',
     "title": 'Esquemas de los Oficios (Typikon)',
     "url": 'https://sites.google.com/site/textosliturgicosortodoxos/typikon/esquemas'},
    {"source": 'textosliturgicos.gs', "jurisdiction": 'Serbian', "type": 'Online',
     "title": 'Pentecostés — sección del Pentecostarion',
     "url": 'https://sites.google.com/site/textosliturgicosortodoxos/pentecostario/pascha11'},
    {"source": 'Ediciones Barek', "jurisdiction": 'Antiochian', "type": 'Portal',
     "title": 'Ediciones Barek — editorial ortodoxa (hub principal)',
     "url": 'https://edicionesbarek.com/'},
    {"source": 'Ediciones Barek', "jurisdiction": 'Antiochian', "type": 'Portal',
     "title": 'Ediciones Barek — catálogo litúrgico',
     "url": 'https://edicionesbarek.com/?page_id=159'},
    {"source": 'Ediciones Barek', "jurisdiction": 'Antiochian', "type": 'Print',
     "title": 'La Divina Liturgia de San Juan Crisóstomo (libro impreso)',
     "url": 'https://edicionesbarekac.mercadoshops.com.mx/MLM-778658033-la-divina-liturgia-de-san-juan-crisostomo-libro-ortodoxo-_JM'},
    {"source": 'Ediciones Barek', "jurisdiction": 'Antiochian', "type": 'Print',
     "title": 'Evangelio Litúrgico (libro impreso)',
     "url": 'https://edicionesbarekac.mercadoshops.com.mx/MLM-872645231-evangelio-liturgico-pasta-dura-_JM'},
    {"source": 'Ediciones Barek', "jurisdiction": 'Antiochian', "type": 'Print',
     "title": 'Colección de 8 Libros Litúrgicos Ortodoxos',
     "url": 'https://edicionesbarekac.mercadoshops.com.mx/MLM-1588866552-coleccion-de-libros-liturgicos-ortodoxos-8-libros-_JM'},
    {"source": 'Ediciones Barek', "jurisdiction": 'Antiochian', "type": 'Print',
     "title": 'Oficios de Semana Santa',
     "url": 'https://edicionesbarekac.mercadoshops.com.mx/MLM-779506656-servicios-de-semana-santa-_JM'},
    {"source": 'Ediciones Barek', "jurisdiction": 'Antiochian', "type": 'Print',
     "title": 'Servicios de Cuaresma',
     "url": 'https://articulo.mercadolibre.com.mx/MLM-875482485-servicios-de-cuaresma-_JM'},
    {"source": 'Internet Archive', "jurisdiction": 'General', "type": 'Archive',
     "title": 'La Divina Liturgia de San Juan Crisóstomo (30 pp., dominio público)',
     "url": 'https://archive.org/details/LaDivinaLiturgiaDeSanJuanCrisstomo'},
    {"source": 'Quotidian Typicon', "jurisdiction": 'EP', "type": 'PDF',
     "title": 'Divinas Liturgias de San Juan Crisóstomo y San Basilio el Grande (PDF genérico, EP)',
     "url": 'https://quotidiantypicon.files.wordpress.com/2020/05/dl-jc-and-basil-generic-final.pdf'},
    {"source": 'OCA', "jurisdiction": 'OCA', "type": 'Portal',
     "title": 'OCA — Buenas Noticias / Good News en Español',
     "url": 'https://www.oca.org/goodnews/espanol'},
    {"source": 'GOARCH', "jurisdiction": 'EP', "type": 'Portal',
     "title": 'GOARCH — Recursos en Español (Greek Orthodox Archdiocese of America)',
     "url": 'https://www.goarch.org/-/spanish-language-resources'},
    {"source": 'Logos Ortodoxo', "jurisdiction": 'Serbian', "type": 'Online',
     "title": 'Logos Ortodoxo — La Divina Liturgia (artículo explicativo, Barcelona)',
     "url": 'https://www.logosortodoxo.com/la-divina-liturgia/'},
    {"source": 'Misión Ortodoxa CL', "jurisdiction": 'General', "type": 'Portal',
     "title": 'Misión Ortodoxa de Chile — Textos Litúrgicos',
     "url": 'http://www.misionortodoxa.cl/index.php/publicaciones/textos-liturgicos'},
]

print(f"Total links: {len(links)}")

# %%
import pandas as pd
from IPython.display import HTML

df = pd.DataFrame(links)

jur_colours = {
    "OCA":        "background-color:#d4edda",
    "Antiochian": "background-color:#cce5ff",
    "EP":         "background-color:#fff3cd",
    "Serbian":    "background-color:#e2d9f3",
    "ROC":        "background-color:#ffd8b4",
    "General":    "background-color:#f8f9fa",
}
type_icons = {"Portal": "🔗 Portal", "Online": "📄 Online", "PDF": "📕 PDF",
              "Print": "📚 Print", "Archive": "🗄 Archive"}

df["jur_html"] = df["jurisdiction"].apply(
    lambda j: f'<span style="{jur_colours.get(j, "")};padding:2px 6px;border-radius:4px">{j}</span>'
)
df["type_label"] = df["type"].map(type_icons).fillna(df["type"])
df["link"] = df["url"].apply(lambda u: f'<a href="{u}" target="_blank">{u}</a>')

HTML(df[["source", "jur_html", "type_label", "title", "link"]].rename(
    columns={"source": "Fuente", "jur_html": "Jurisdicción",
             "type_label": "Tipo", "title": "Título", "link": "URL"}
).to_html(escape=False, index=False))
